# %% [markdown]
# <a href="https://colab.research.google.com/github/LSYeon02/AI_1/blob/main/solor_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 그래프에서 한글 인식하기: 코드 실행 후 런타임 다시시작하기 -코랩
#코드 실행 후 런타임 다시시작하기 -코랩
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 27 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (9,868 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
#@title 사전 작업 (실행후 ok 나오면 완료)
#파일 불러오기
import pandas as pd
import numpy as np
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import random

from google.colab import files
#upload = files.upload()   #코랩에서 활성화

#파일열기
#file = input('파일 이름을 입력하세요.(확장자 포함) --> ') 
#df=pd.read_csv(file,sep='\t', encoding='cp949')  # , 등으로 나눠진 파일일 때
#df=pd.read_csv(file, encoding='cp949')
#print('OK!')

#@title 함수 정의하기
def plot():
  plt.rc('font', family='NanumGothic') #한글입력
  plt.figure(dpi=100) #그래프 크기

  graph_name1= input('① 그래프의 제목을 입력하세요.-->')
  plt.title(graph_name1)

  try:
      for i in range(3):
          graph_type1 = input('② 그래프 형태를 선택하여 입력하세요. (히스토그램, 막대, 꺾은선, 산점도)-->')
          if graph_type1 == '히스토그램':
              vari = input('③ 히스토그램으로 나타낼 항목은?: ')
              for i in range(3):
                  scale1 = input('④ x축의 스케일을 선택하세요.(선형, 로그): ')
                  if scale1 == '로그':
                      A = np.logspace(np.log10(0.01),np.log(10.0),1000)
                      plt.xscale('log')
                      break
                  elif scale1 == '선형':
                      A = 100
                      break
                  else:
                      print('잘못 입력하였습니다. 다시 시도하세요.')
              plt.hist(ast[vari], bins = A)
              plt.xlabel(vari)
              plt.ylabel('행성 개수')
              plt.xticks(size = 5, rotation= 90)
              plt.show()
              break
    
          elif graph_type1 == '막대':
              varix1 = input('③ x축에 들어갈 항목은?: ')
              variy1 = input('④ y축에 들어갈 항목은?: ')
              plt.bar(ast[varix1], ast[variy1])
              for i in range(3):
                  scale1 = input('⑤ x축의 스케일을 선택하세요.(선형, 로그): ')
                  if scale1 == '로그':
                      plt.xscale('log')
                      break
                  elif scale1 == '선형':
                      pass
                      break
                  else:
                      print('잘못 입력하였습니다. 다시 시도하세요.')
              for i in range(3):
                  scale1 = input('⑥ y축의 스케일을 선택하세요.(선형, 로그): ')
                  if scale1 == '로그':
                      plt.yscale('log')
                      break
                  elif scale1 == '선형':
                      pass
                      break
                  else:
                      print('잘못 입력하였습니다. 다시 시도하세요.')
              plt.xlabel(varix1)
              plt.ylabel(variy1)
              plt.xticks(size = 5, rotation= 90)
              plt.show()
              break

          elif graph_type1 == '꺾은 선':
              varix2 = input('③ x축에 들어갈 항목은?: ')
              variy2 = input('④ y축에 들어갈 항목은?: ')
              plt.plot(ast[varix2], ast[variy2])  
              for i in range(3):
                  scale1 = input('⑤ x축의 스케일을 선택하세요.(선형, 로그): ')
                  if scale1 == '로그':
                      plt.xscale('log')
                      break
                  elif scale1 == '선형':
                      pass
                      break
                  else:
                      print('잘못 입력하였습니다. 다시 시도하세요.')
              for i in range(3):
                  scale1 = input('⑥ y축의 스케일을 선택하세요.(선형, 로그): ')
                  if scale1 == '로그':
                      plt.yscale('log')
                      break
                  elif scale1 == '선형':
                      pass
                      break
                  else:
                      print('잘못 입력하였습니다. 다시 시도하세요.')
              plt.xlabel(varix2)
              plt.ylabel(variy2)
              plt.xticks(size = 5, rotation= 90)
              plt.show()
              break
    
          elif graph_type1 == '산점도':
              varix3 = input('③ x축에 들어갈 항목은?: ')
              variy3 = input('④ y축에 들어갈 항목은?: ')
              plt.scatter(ast[varix3],ast[variy3])
              for i in range(3):
                  scale1 = input('⑤ x축의 스케일을 선택하세요.(선형, 로그): ')
                  if scale1 == '로그':
                      plt.xscale('log')
                      break
                  elif scale1 == '선형':
                      pass
                      break
                  else:
                      print('잘못 입력하였습니다. 다시 시도하세요.')
              for i in range(3):
                  scale1 = input('⑥ y축의 스케일을 선택하세요.(선형, 로그): ')
                  if scale1 == '로그':
                      plt.yscale('log')
                      break
                  elif scale1 == '선형':
                      pass
                      break
                  else:
                      print('잘못 입력하였습니다. 다시 시도하세요.')
              plt.xlabel(varix3)
              plt.ylabel(variy3)
              plt.xticks(size = 5, rotation= 90)
              plt.show()
              break
        
          else:
              print('잘못 입력하였습니다. 다시 시도하세요.')

  except: 
      print('그래프 그리기에 실패하였습니다. 다시 시도하려면 코드를 다시 실행시키세요.')
      pass

#조건 함수 정의하기
#함수 정의
def conA(a, x, y):
     if '크다' in y:
        return ast[a] > x
     else:
        return ast[a] < x

def conB(a, x, M, y ):
    if '그리고' in M:
        return (ast[a] > x) & (ast[a] < y)
    else:
        return (ast[a] > x) or (ast[a] < y)

#    x, y1, a, M, y2, b = input('조건: ')
#    return (exo.x,y1,a),M,(exo.x,y2,b)


print('OK!')
# Out:
# OK!

# %%
#@title (1) 행성의 궤도를 그려봅시다
plt.figure(figsize=(20,20))
plt.rc('font', family='NanumGothic')
plt.title('행성의 궤도')
for i in range(8):
  name = input('행성이름')
  print(i+1, name )
  a=float(input('행성 궤도의 장반경은?'))
  e=float(input('행성 궤도의 이심률은?'))
  b= a*((1-e**2)**(1/2))
  c=(a**2-b**2)**0.5
  x=np.linspace(-a-10,a+10,3000)
  y1=(b**2-(b**2/a**2)*(x-(1-c))**2)**0.5
  y2=-(b**2-(b**2/a**2)*(x-(1-c))**2)**0.5
  #plt.hlines(0,-a,+a,color='black',linestyle='--')##(y축 위치, x축 시작점, x축 끝점)
  #plt.vlines(0,-b,+b,color='black',linestyle='--')##(x축 위치, y축 시작점, y축 끝점)
  plt.grid(linestyle='-.')
  #plt.scatter(-c,0,c='r')
  plt.scatter(1,0,c='r')
  #plt.scatter(0,0,c='b')
  #plt.text(-c,-2,'('+str(round(-c,1))+', 0)')
  #plt.text(c,-2,'('+str(round(c,1))+', 0)')
  #plt.text(-1.5,1.5,'e='+str(round(e,2)),size=13)
  plt.plot(x,y1,c='k')
  plt.plot(x,y2,c='k')
  #plt.xlim(-a-1,a+1)
  #plt.ylim(-a-1,a+1)
  

plt.show()
# Out:
# 행성이름수성
# 1 수성
# 행성 궤도의 장반경은?0.39
# 행성 궤도의 이심률은?0.206
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in sqrt
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in sqrt
# 행성이름금성
# 2 금성
# 행성 궤도의 장반경은?0.7
# 행성 궤도의 이심률은?0.007
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in sqrt
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in sqrt
# 행성이름지구
# 3 지구
# 행성 궤도의 장반경은?1
# 행성 궤도의 이심률은?0.017
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in sqrt
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in sqrt
# 행성이름화성
# 4 화성
# 행성 궤도의 장반경은?1.52
# 행성 궤도의 이심률은?0.093
# ...

# %%
#@title (2) 행성의 주기-장반경 관계 그래프를 그려봅시다
plt.figure(figsize=(10,10))
plt.rc('font', family='NanumGothic')
plt.title('행성의 주기-장반경 관계')
for i in range(8):
  name = input('행성이름')
  p = float(input('행성의 공전 주기는?'))
  a = float(input('행성의 공전궤도 긴 반지름(장반경)은?'))
  plt.scatter(p**2, a**3)
x=np.linspace(-1,30000,300000)
y=x
plt.plot(x,y,label='y = x')
plt.legend()
plt.xlabel('주기**2')
plt.ylabel('장반경**3')
plt.show()
# Out:
# 행성이름ㅏ
# 행성의 공전 주기는?11
# 행성의 공전궤도 긴 반지름(장반경)은?11
# 행성이름ㅓ3
# 행성의 공전 주기는?4
# 행성의 공전궤도 긴 반지름(장반경)은?5
# 행성이름9
# 행성의 공전 주기는?84
# 행성의 공전궤도 긴 반지름(장반경)은?20
# 행성이름ㅇ
# 행성의 공전 주기는?1.8
# 행성의 공전궤도 긴 반지름(장반경)은?1.52
# 행성이름ㅇ
# 행성의 공전 주기는?30
# 행성의 공전궤도 긴 반지름(장반경)은?10
# 행성이름ㅇ
# 행성의 공전 주기는?1
# 행성의 공전궤도 긴 반지름(장반경)은?1
# 행성이름아
# 행성의 공전 주기는?8
# 행성의 공전궤도 긴 반지름(장반경)은?8
# 행성이름아
# 행성의 공전 주기는?100
# 행성의 공전궤도 긴 반지름(장반경)은?100
